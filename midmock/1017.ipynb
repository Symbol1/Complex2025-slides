# %% [markdown]
# # Midmock helper

# %% [markdown]
# ## Domain coloring

# %%
var('z')
complex_plot( (z - 3 - 4*i) * (z - 4 - i)^2 / (z - 1 - i)^2 / (z - 3 - 2*i), (0, 5), (0, 5)).show(figsize=(10, 10))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
complex_plot( (z - 3 - 4*i) * (z - 4 - i)^2 / (z - 1 - i)^2 / (z - 3 - 2*i), (-5, 15), (-5, 15)).show(figsize=(10, 10))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# ## Numerical integration

# %%
integral( exp(z^2), z, 0, pi/2 + i).n()
# Out:
# -0.896483992063044 + 1.65550045787695*I

# %%
(pi/2 + i).n()^2
# Out:
# 1.46740110027234 + 3.14159265358979*I

# %%
taylor(sin(cos(z)), z, 0, 6)
# Out:
# 1/720*z^6*(14*cos(1) + 15*sin(1)) + 1/24*z^4*(cos(1) - 3*sin(1)) - 1/2*z^2*cos(1) + sin(1)

# %% [markdown]
# ## Root finding

# %%
_.<z> = CC['z']

# %%
parent(i)
# Out:
# Number Field in I with defining polynomial x^2 + 1 with I = 1*I

# %%
f = (z - 0.5 - 0.5*I) * (z - 0.5 - 2.5*I)^2 * (z - 1.5 - 0.5*I)
f
# Out:
# z^4 + (-3.00000000000000 - 6.00000000000000*I)*z^3 + (-8.50000000000000 + 14.5000000000000*I)*z^2 + (19.0000000000000 - 2.50000000000000*I)*z - 5.50000000000000 - 4.75000000000000*I

# %%
f -= 0.25*I
f += 0.5
f += 0.5*I*z
f
# Out:
# z^4 + (-3.00000000000000 - 6.00000000000000*I)*z^3 + (-8.50000000000000 + 14.5000000000000*I)*z^2 + (19.0000000000000 - 2.00000000000000*I)*z - 5.00000000000000 - 5.00000000000000*I

# %%
line([(0, 1), (3, 1)]) + \
line([(0, 2), (3, 2)]) + \
line([(1, 0), (1, 3)]) + \
line([(2, 0), (2, 3)]) + \
points([z for z, m in f.roots()])
# Out:
# Graphics object consisting of 5 graphics primitives

# %%
Rectangle([(0, 0), (1, 1)])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 Rectangle([(Integer(0), Integer(0)), (Integer(1), Integer(1))])
#
# NameError: name 'Rectangle' is not defined
